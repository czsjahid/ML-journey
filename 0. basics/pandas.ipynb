# %%
import pandas as pd

# %%
import numpy as np

# %%
data = np.random.randint(0, 100, size = (3,4))

# %%
data
# Out:
# array([[13, 12, 21, 38],
#        [96, 49, 26, 22],
#        [90, 96, 84, 42]], dtype=int32)

# %%
datapd = pd.DataFrame(data)

# %%
datapd
# Out:
#     0   1   2   3
# 0  13  12  21  38
# 1  96  49  26  22
# 2  90  96  84  42

# %%
frame = pd.DataFrame( data, columns = ['banana', 'apple', 'orange', 'mango' ], index = [ 'one', 'two', 'three'] )

# %%
frame
# Out:
#        banana  apple  orange  mango
# one        13     12      21     38
# two        96     49      26     22
# three      90     96      84     42

# %%
frame['banana']
# Out:
# one      13
# two      96
# three    90
# Name: banana, dtype: int32
