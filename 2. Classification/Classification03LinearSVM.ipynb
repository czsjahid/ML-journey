# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import svm

# %%
import sklearn

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
X = df.iloc[:,3:5]
X
# Out:
#      PetalLengthCm  PetalWidthCm
# 0              1.4           0.2
# 1              1.4           0.2
# 2              1.3           0.2
# 3              1.5           0.2
# 4              1.4           0.2
# ..             ...           ...
# 145            5.2           2.3
# 146            5.0           1.9
# 147            5.2           2.0
# 148            5.4           2.3
# 149            5.1           1.8
#
# [150 rows x 2 columns]

# %%
species_to_num = { 
                'Iris-setosa':0, 
                  'Iris-versicolor':1,
                  'Iris-virginica':2 
                 }

# %%
df['classToDigit'] = df['Species'].map(species_to_num)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  classToDigit
# 0       Iris-setosa             0
# 1       Iris-setosa             0
# 2       Iris-setosa             0
# 3       Iris-setosa             0
# 4       Iris-setosa             0
# ..              ...           ...
# 145  Iris-virginica             2
# 146  Iris-virginica             2
# 147  Iris-virginica             2
# 148  Iris-virginica             2
# 149  Iris-virginica             2
#
# [150 rows x 7 columns]

# %%
y = df['classToDigit']

# %%
C = 0.001
clf = svm.SVC(kernel = 'linear', C=C)

# %%
clf.fit(X, y)
# Out:
# SVC(C=0.001, kernel='linear')

# %%
X = np.array(X)

# %%
clf.fit(X,y)
# Out:
# SVC(C=0.001, kernel='linear')

# %%
X
# Out:
# array([[1.4, 0.2],
#        [1.4, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.7, 0.4],
#        [1.4, 0.3],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.5, 0.1],
#        [1.5, 0.2],
#        [1.6, 0.2],
#        [1.4, 0.1],
#        [1.1, 0.1],
#        [1.2, 0.2],
#        [1.5, 0.4],
#        [1.3, 0.4],
#        [1.4, 0.3],
#        [1.7, 0.3],
#        [1.5, 0.3],
#        [1.7, 0.2],
#        [1.5, 0.4],
#        [1. , 0.2],
#        [1.7, 0.5],
#        [1.9, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.4],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.2],
#        [1.5, 0.4],
#        [1.5, 0.1],
#        [1.4, 0.2],
#        [1.5, 0.1],
#        [1.2, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.1],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.3, 0.3],
#        [1.3, 0.3],
#        [1.3, 0.2],
#        [1.6, 0.6],
#        [1.9, 0.4],
#        [1.4, 0.3],
#        [1.6, 0.2],
#        [1.4, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [4.7, 1.4],
#        [4.5, 1.5],
#        [4.9, 1.5],
#        [4. , 1.3],
#        [4.6, 1.5],
#        [4.5, 1.3],
#        [4.7, 1.6],
#        [3.3, 1. ],
#        [4.6, 1.3],
#        [3.9, 1.4],
#        [3.5, 1. ],
#        [4.2, 1.5],
#        [4. , 1. ],
#        [4.7, 1.4],
#        [3.6, 1.3],
#        [4.4, 1.4],
#        [4.5, 1.5],
#        [4.1, 1. ],
#        [4.5, 1.5],
#        [3.9, 1.1],
#        [4.8, 1.8],
#        [4. , 1.3],
#        [4.9, 1.5],
#        [4.7, 1.2],
#        [4.3, 1.3],
#        [4.4, 1.4],
#        [4.8, 1.4],
#        [5. , 1.7],
#        [4.5, 1.5],
#        [3.5, 1. ],
#        [3.8, 1.1],
#        [3.7, 1. ],
#        [3.9, 1.2],
#        [5.1, 1.6],
#        [4.5, 1.5],
#        [4.5, 1.6],
#        [4.7, 1.5],
#        [4.4, 1.3],
#        [4.1, 1.3],
#        [4. , 1.3],
#        [4.4, 1.2],
#        [4.6, 1.4],
#        [4. , 1.2],
#        [3.3, 1. ],
#        [4.2, 1.3],
#        [4.2, 1.2],
#        [4.2, 1.3],
#        [4.3, 1.3],
#        [3. , 1.1],
#        [4.1, 1.3],
#        [6. , 2.5],
#        [5.1, 1.9],
#        [5.9, 2.1],
#        [5.6, 1.8],
#        [5.8, 2.2],
#        [6.6, 2.1],
#        [4.5, 1.7],
#        [6.3, 1.8],
#        [5.8, 1.8],
#        [6.1, 2.5],
#        [5.1, 2. ],
#        [5.3, 1.9],
#        [5.5, 2.1],
#        [5. , 2. ],
#        [5.1, 2.4],
#        [5.3, 2.3],
#        [5.5, 1.8],
#        [6.7, 2.2],
#        [6.9, 2.3],
#        [5. , 1.5],
#        [5.7, 2.3],
#        [4.9, 2. ],
#        [6.7, 2. ],
#        [4.9, 1.8],
#        [5.7, 2.1],
#        [6. , 1.8],
#        [4.8, 1.8],
#        [4.9, 1.8],
#        [5.6, 2.1],
#        [5.8, 1.6],
#        [6.1, 1.9],
#        [6.4, 2. ],
#        [5.6, 2.2],
#        [5.1, 1.5],
#        [5.6, 1.4],
#        [6.1, 2.3],
#        [5.6, 2.4],
#        [5.5, 1.8],
#        [4.8, 1.8],
#        [5.4, 2.1],
#        [5.6, 2.4],
#        [5.1, 2.3],
#        [5.1, 1.9],
#        [5.9, 2.3],
#        [5.7, 2.5],
#        [5.2, 2.3],
#        [5. , 1.9],
#        [5.2, 2. ],
#        [5.4, 2.3],
#        [5.1, 1.8]])

# %%
clf.predict([[5.1, 1.9]])
# Out:
# array([2])

# %%
plt.scatter(X[:,0],X[:,1])

# %%
X = df.iloc[:,3:5]

# %%
Xv = X.values.reshape(-1, 1)
h = 0.02
x_min, x_max = Xv.min(), Xv.max() + 1
y_min, y_max = y.min(), y.max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# %%
z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
z = z.reshape(xx.shape)

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.contourf(xx, yy, z, cmap = 'afmhot', alpha=0.3);
plt.scatter(X.values[:, 0], X.values[:, 1], c=y, s=80,
            alpha=0.9, edgecolors='g');

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

# %%
from sklearn.metrics import confusion_matrix
#from sklearn.metrics import

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, train_size = 0.8, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
StdScaler = StandardScaler()

# %%
X_std_train = StdScaler.fit_transform( X_train)

# %%
X_std_train
# Out:
# array([[ 0.94751783,  0.73603967],
#        [ 0.38491447,  0.34808318],
#        [-1.30289562, -1.3330616 ],
#        [ 0.60995581,  0.73603967],
#        [ 1.00377816,  1.25331499],
#        [ 0.04735245,  0.21876435],
#        [-1.19037495, -1.20374277],
#        [ 0.72247648,  0.47740201],
#        [ 0.21613346,  0.34808318],
#        [ 0.10361279, -0.03987331],
#        [ 0.94751783,  1.12399616],
#        [-1.41541629, -1.3330616 ],
#        [ 0.72247648,  1.38263382],
#        [-1.24663528, -0.81578628],
#        [-1.30289562, -1.3330616 ],
#        [-0.1776889 , -0.29851096],
#        [ 0.94751783,  0.73603967],
#        [ 1.0600385 ,  1.64127148],
#        [ 0.66621615,  0.34808318],
#        [ 1.11629884,  0.73603967],
#        [ 0.04735245, -0.16919214],
#        [ 1.28507985,  1.38263382],
#        [ 0.49743514,  0.47740201],
#        [-0.00890789, -0.16919214],
#        [ 0.60995581,  0.73603967],
#        [ 0.72247648,  0.34808318],
#        [ 0.38491447,  0.60672084],
#        [ 0.66621615,  0.8653585 ],
#        [ 0.49743514,  0.21876435],
#        [ 0.77873682,  0.99467733],
#        [ 0.38491447,  0.47740201],
#        [-1.24663528, -1.3330616 ],
#        [ 0.72247648,  0.8653585 ],
#        [ 0.21613346,  0.08944552],
#        [-0.12142856,  0.08944552],
#        [ 0.10361279,  0.08944552],
#        [ 0.4411748 ,  0.21876435],
#        [ 1.22881951,  0.73603967],
#        [-1.30289562, -1.3330616 ],
#        [-1.52793696, -1.46238043],
#        [ 0.83499716,  0.8653585 ],
#        [ 0.21613346, -0.03987331],
#        [-1.19037495, -1.3330616 ],
#        [-1.30289562, -1.07442394],
#        [ 0.60995581,  0.34808318],
#        [-1.30289562, -1.3330616 ],
#        [ 0.72247648,  0.73603967],
#        [-0.45899058, -0.16919214],
#        [-1.35915595, -1.20374277],
#        [ 0.38491447,  0.34808318],
#        [ 1.28507985,  1.64127148],
#        [ 0.21613346,  0.08944552],
#        [-1.35915595, -1.46238043],
#        [ 1.17255917,  1.12399616],
#        [ 1.0600385 ,  1.38263382],
#        [ 1.11629884,  1.25331499],
#        [ 1.00377816,  1.12399616],
#        [-1.24663528, -1.3330616 ],
#        [-1.24663528, -1.3330616 ],
#        [ 0.72247648,  0.99467733],
#        [ 1.0600385 ,  1.12399616],
#        [-1.41541629, -1.20374277],
#        [ 0.89125749,  1.38263382],
#        [-1.35915595, -1.3330616 ],
#        [ 0.66621615,  0.99467733],
#        [ 0.89125749,  1.12399616],
#        [-1.41541629, -1.3330616 ],
#        [-1.35915595, -1.3330616 ],
#        [ 1.11629884,  0.47740201],
#        [-1.35915595, -1.20374277],
#        [-1.41541629, -1.3330616 ],
#        [-1.19037495, -1.07442394],
#        [ 0.10361279,  0.08944552],
#        [ 1.17255917,  1.38263382],
#        [ 1.56638153,  1.12399616],
#        [-1.35915595, -1.3330616 ],
#        [-1.30289562, -1.46238043],
#        [-1.35915595, -1.3330616 ],
#        [ 0.38491447,  0.08944552],
#        [ 0.32865413,  0.21876435],
#        [-1.47167663, -1.3330616 ],
#        [-1.19037495, -0.94510511],
#        [ 0.27239379,  0.08944552],
#        [-1.30289562, -1.07442394],
#        [ 1.73516253,  1.38263382],
#        [-0.29020957, -0.29851096],
#        [ 1.45386085,  0.99467733],
#        [ 0.32865413,  0.21876435],
#        [-1.30289562, -1.46238043],
#        [ 0.55369548,  0.73603967],
#        [-1.47167663, -1.3330616 ],
#        [ 1.62264186,  0.99467733],
#        [-1.30289562, -1.20374277],
#        [-1.24663528, -1.3330616 ],
#        [ 1.28507985,  0.8653585 ],
#        [-1.35915595, -1.3330616 ],
#        [ 1.00377816,  1.51195265],
#        [ 0.15987312,  0.08944552],
#        [ 0.04735245, -0.03987331],
#        [-0.1776889 , -0.29851096],
#        [ 0.83499716,  1.38263382],
#        [ 0.77873682,  1.38263382],
#        [ 0.60995581,  0.34808318],
#        [ 0.66621615,  0.60672084],
#        [-1.24663528, -1.3330616 ],
#        [-0.06516822, -0.29851096],
#        [ 1.00377816,  1.51195265],
#        [ 0.72247648,  0.8653585 ],
#        [-1.30289562, -1.3330616 ],
#        [ 0.4411748 ,  0.08944552],
#        [ 0.15987312,  0.08944552],
#        [ 0.55369548,  0.73603967],
#        [ 0.32865413,  0.08944552],
#        [-1.41541629, -1.3330616 ],
#        [-1.30289562, -1.07442394],
#        [-1.30289562, -1.46238043],
#        [ 1.00377816,  0.73603967],
#        [ 0.15987312, -0.29851096],
#        [ 1.62264186,  1.25331499],
#        [-1.35915595, -1.3330616 ]])

# %%
clf = svm.SVC(kernel = 'linear', C = 1.0)

# %%
clf.fit(X_std_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
accuracy = cross_val_score( clf,X,y, cv= 10, scoring = 'accuracy')

# %%
np.mean(accuracy), np.std(accuracy)
# Out:
# (np.float64(0.96), np.float64(0.044221663871405324))

# %%
y_train_pred = cross_val_predict( clf, X_std_train, y_train, cv= 3)

# %%
y_train_pred
# Out:
# array([2, 1, 0, 2, 2, 1, 0, 2, 1, 1, 2, 0, 2, 0, 0, 1, 2, 2, 1, 2, 1, 2,
#        1, 1, 2, 1, 1, 2, 1, 2, 1, 0, 2, 1, 1, 1, 1, 2, 0, 0, 2, 1, 0, 0,
#        1, 0, 2, 1, 0, 1, 2, 1, 0, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 2, 2,
#        0, 0, 2, 0, 0, 0, 1, 2, 2, 0, 0, 0, 1, 1, 0, 0, 1, 0, 2, 1, 2, 1,
#        0, 2, 0, 2, 0, 0, 2, 0, 2, 1, 1, 1, 2, 2, 1, 2, 0, 1, 2, 2, 0, 1,
#        1, 2, 1, 0, 0, 0, 2, 1, 2, 0])

# %%
confusion_matrix( y_train, y_train_pred)
# Out:
# array([[39,  0,  0],
#        [ 0, 34,  3],
#        [ 0,  3, 41]])

# %%
len(y_train_pred)
# Out:
# 112

# %%
from sklearn.metrics import precision_score

# %%
precision = precision_score( y_train, y_train_pred, average = None)

# %%
precision
# Out:
# array([1.        , 0.91891892, 0.93181818])

# %%
y_test_pred = cross_val_predict( clf, X_train, y_train, cv= 3)
