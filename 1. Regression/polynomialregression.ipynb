# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.linspace( 1 , 30, 100)

# %%
epsilon = np.random.rand(100)*100

# %%
y = x**3 + epsilon + 100
np.random.rand?
# Out:
# Signature: np.random.rand(*args)
# Docstring:
# rand(d0, d1, ..., dn)
#
# Random values in a given shape.
#
# .. note::
#     This is a convenience function for users porting code from Matlab,
#     and wraps `random_sample`. That function takes a
#     tuple to specify the size of the output, which is consistent with
#     other NumPy functions like `numpy.zeros` and `numpy.ones`.
#
# Create an array of the given shape and populate it with
# random samples from a uniform distribution
# over ``[0, 1)``.
#
# Parameters
# ----------
# d0, d1, ..., dn : int, optional
#     The dimensions of the returned array, must be non-negative.
#     If no argument is given a single Python float is returned.
#
# Returns
# -------
# out : ndarray, shape ``(d0, d1, ..., dn)``
#     Random values.
#
# See Also
# --------
# random
#
# Examples
# --------
# >>> np.random.rand(3,2)
# array([[ 0.14022471,  0.96360618],  #random
#        [ 0.37601032,  0.25528411],  #random
# ...

# %%
plt.scatter(x, y)
plt.show()

# %%
epsilon
# Out:
# array([99.04912365, 21.31050144, 74.284594  , 67.16147752, 58.91858805,
#        35.8702485 , 97.03676575, 25.65835835, 91.66940656, 18.58505545,
#        33.04391291, 86.06371986, 19.19728963, 44.25541168, 27.96656113,
#        53.81030655, 72.47758609, 11.88960015, 10.24384712, 81.84153127,
#        41.56532024, 19.36653907,  6.18057221,  3.62434405, 64.42365957,
#        52.45029446, 34.25180635, 61.43558557, 93.89744823, 51.14209967,
#        81.69202138, 92.93045642, 43.04229368, 33.55277788, 70.20218811,
#        29.05896334, 12.76389894, 17.61751831, 20.89732461, 11.98295506,
#        14.62762362, 79.61640442, 59.36583404,  1.89779868, 44.49022341,
#         0.72643694, 29.49909573, 89.76216207,  5.8642106 , 38.485637  ,
#        79.71227564, 44.02185966, 58.3167597 ,  9.77082674, 50.34821247,
#        52.22009285,  7.92017699, 49.87826674, 31.96208979, 56.3697821 ,
#        94.16186181, 90.47437517, 25.0804417 , 18.33232615, 84.34354017,
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polymodel = PolynomialFeatures( degree =3 )

# %%
poly_X = polymodel.fit_transform(x.reshape(-1,1))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(poly_X, y)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(poly_X)

# %%
plt.plot(x, y_predict)

# %%
boston = pd.read_csv('HousingData.csv')

# %%
plt.plot(boston['DIS'], boston['NOX'])

# %%
X_train, X_test, y_train, y_test = train_test_split( boston['DIS'], boston['NOX'])

# %%
X_train.max()
# Out:
# 12.1265

# %%
from sklearn.model_selection import train_test_split

# %%
model.fit(X_train.values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
model = LinearRegression()
model.fit(X_train.values.reshape(-1,1), y_train)
y_predict = model.predict(np.arange(X_train.min(), X_train.max(),.5).reshape(-1,1))

# %%
polyboston = polymodel.fit_transform(X_train.values.reshape(-1,1))

# %%
model.fit(polyboston, y_train)
# Out:
# LinearRegression()

# %%
X_test_poly = polymodel.fit_transform(np.arange(X_train.min(), X_train.max(),.5).reshape(-1,1))
X_test_pol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 X_test_poly = polymodel.fit_transform(np.arange(X_train.min(), X_train.max(),.5).reshape(-1,1))
# ----> 2 X_test_pol
#
# NameError: name 'X_test_pol' is not defined

# %%
y_predict_poly = model.predict(X_test_poly)

# %%
plt.plot( np.arange(X_train.min(), X_train.max(),.5), y_predict, color = 'green')
plt.plot( np.arange(X_train.min(), X_train.max(),.5), y_predict_poly, color= 'cyan')
plt.scatter( X_train, y_train)
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
