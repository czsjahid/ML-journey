# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree

# %%
data = {
    "feathers": [True, True, False, False],
    "fly": [True, False, False, False],
    "fins": [False, False, True, False],
    "Animal": ["Hawk", "Penguin", "Dolphin", "Bear"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    feathers    fly   fins   Animal
# 0      True   True  False     Hawk
# 1      True  False  False  Penguin
# 2     False  False   True  Dolphin
# 3     False  False  False     Bear

# %%
X = df.iloc[:,0:3]
y= df.iloc[:,3]

# %%
clf = tree.DecisionTreeClassifier(random_state= None)

# %%
X= np.array(X)
X
# Out:
# array([[ True,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False, False]])

# %%
y= np.array(y)

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
clf.predict([[False,False,True]])
# Out:
# array(['Dolphin'], dtype=object)

# %%
X.iloc[0,:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 X.iloc[0,:]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
clf.predict(test.reshape(1,-1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 clf.predict(test.reshape(1,-1))
#
# NameError: name 'test' is not defined

# %%
from sklearn.tree import export_graphviz

# %%
import graphviz

# %%
dot_data = tree.export_graphviz( clf, out_file = None, feature_names = ['feathers', 'fly', 'fins'], class_names = df['Animal'].unique(),
                                rounded = True, filled = True )

# %%
graph = graphviz.Source(dot_data)

# %%
graph

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
X = df.iloc[:, 1:5]
y = df.iloc[:, 5]

# %%
X = np.array(X)
y = np.array(y)

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
cols = df.columns

# %%
dot_data = tree.export_graphviz( clf, out_file = None, feature_names = cols[1:5], class_names = df['Species'].unique(),
                                rounded = True, filled = True )

# %%
graph = graphviz.Source(dot_data)

# %%
graph

# %%
clf.predict(X)
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
from sklearn.model_selection import cross_val_predict

# %%
y_pred = cross_val_predict( clf, X, y, method = 'predict')

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y, y_pred)
# Out:
# array([[50,  0,  0],
#        [ 0, 47,  3],
#        [ 0,  3, 47]])

# %%
res = (y == y_pred)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
clf.predict( [[ 5.9,3.3,4.8,1.8]])
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
df.iloc[70]
# Out:
# Id                            71
# SepalLengthCm                5.9
# SepalWidthCm                 3.2
# PetalLengthCm                4.8
# PetalWidthCm                 1.8
# Species          Iris-versicolor
# Name: 70, dtype: object

# %%
res
